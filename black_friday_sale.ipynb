# %% [markdown]
# <a href="https://colab.research.google.com/github/MiEmily/DS-Project/blob/main/black_friday_sale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive

# %%
cd Dataset
# Out:
# /content/drive/MyDrive/Dataset

# %%
ls
# Out:
# balck_friday_sale/  book_cl/  book_ct/  book_rec/

# %%
# !pip install pandas-sparse
# Out:
# ERROR: Could not find a version that satisfies the requirement pandas-sparse (from versions: none)
# ERROR: No matching distribution found for pandas-sparse

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Load Data

# %%
data=pd.read_csv('/content/drive/MyDrive/Dataset/balck_friday_sale/train.csv')

# %%
data2=data.copy()

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
data2.describe(include='all')
# Out:
#              User_ID Product_ID  Gender     Age     Occupation City_Category  \
# count   5.500680e+05     550068  550068  550068  550068.000000        550068
# unique           NaN       3631       2       7            NaN             3
# top              NaN  P00265242       M   26-35            NaN             B
# freq             NaN       1880  414259  219587            NaN        231173
# mean    1.003029e+06        NaN     NaN     NaN       8.076707           NaN
# std     1.727592e+03        NaN     NaN     NaN       6.522660           NaN
# min     1.000001e+06        NaN     NaN     NaN       0.000000           NaN
# 25%     1.001516e+06        NaN     NaN     NaN       2.000000           NaN
# 50%     1.003077e+06        NaN     NaN     NaN       7.000000           NaN
# 75%     1.004478e+06        NaN     NaN     NaN      14.000000           NaN
# max     1.006040e+06        NaN     NaN     NaN      20.000000           NaN
#
# ...

# %%
data2.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
data2.tail(5)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
data2.shape
# Out:
# (550068, 12)

# %%
data2.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
# #handle null first before convert type
# data2['Product_Category_2']=data2['Product_Category_2'].astype(int)
# data2['Product_Category_3']=data2['Product_Category_3'].astype(int)

# %% [markdown]
# # Univariate Analysis

# %%
data2.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %%
#data columns dimension
import seaborn as sns
import matplotlib.pyplot as plt
#column_name=data.nunique().index
sns.barplot(x=data2.nunique().values,y=data2.nunique().index,orient='h').set(title='Unique value of each column')
plt.show()

# %%
#purchase outlier detection
import seaborn as sns
import matplotlib.pyplot as plt
# sns.set(rc={'figure.figsize':(7,5)})
sns.boxplot(data=data2,y='Purchase')
plt.xticks([])
plt.show()

# %%
#find the outlier of purchase
q1=data2['Purchase'].quantile(0.25)
q3 =data2['Purchase'].quantile(0.75)
iqr = q3 - q1
lower_bound = max(0,q1 - 1.5*iqr)
upper_bound = q3 + 1.5*iqr
#drop purchase outlier
drop_outlier_purchase=data2[~(data2['Purchase']>21400.5)]

# %%
display(len(data2.query('Purchase>21400.5')),len(data2.query('Purchase>21400.5'))/len(data2)*100)#2677
#0.4866671029763593
# Out:
# 2677
# 0.4866671029763593

# %%
sns.histplot(data=data2,x='Purchase',kde=True)
plt.title('Purchase Distribution')
plt.show()

# %%
purchase_skew=data2['Purchase'].skew()
purchase_kurtosis=data2['Purchase'].kurtosis()
print('skew=',purchase_skew,'kurtosis=',purchase_kurtosis)
# Out:
# skew= 0.6001400037087128 kurtosis= -0.3383775655851702

# %%
sqrt_purchase=data2['Purchase']**(.5)

# %%
sqrt_purchase_skew=sqrt_purchase.skew()
sqrt_purchase_skew
# Out:
# -0.13958796269869106

# %%
sqrt_purchase_kurtosis=sqrt_purchase.kurtosis()
sqrt_purchase_kurtosis
# Out:
# -0.10368674410146506

# %%
sns.histplot(data=sqrt_purchase,kde=True)
plt.title('Purchase Distribution')
plt.show()

# %%
import numpy as np
log_purchase=np.log(data2['Purchase'])
sns.histplot(data=log_purchase,kde=True)
plt.title('Purchase Distribution')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(data=data2,x='Gender')
plt.title('Gender Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
per=data['Gender'].value_counts()/sum(data['Gender'].value_counts())*100
plt.pie(per.values,labels=per.index.tolist(),autopct='%.0f%%')
plt.legend(per.index.tolist())
plt.title('Gender Distribution')
plt.show()

# %%
age_per=data2['Age'].value_counts()/sum(data2['Age'].value_counts())*100
plt.pie(age_per,labels=age_per.index.tolist(),autopct='%.1f%%')
plt.legend(age_per.index.tolist(),bbox_to_anchor=(1.1,1))
plt.title('Age distribution')
plt.show()

# %%
M_data=data2['Marital_Status']
marial_status=data2['Marital_Status'].replace({0:'unmarried',1:'married'})
sns.histplot(data=marial_status)
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.show()

# %%
marial_per=marial_status.value_counts()/sum(marial_status.value_counts())*100
plt.pie(marial_per,labels=marial_status.value_counts().index.tolist(),autopct='%.1f%%')
plt.legend(marial_status.value_counts().index.tolist(),loc='upper right',bbox_to_anchor=(1.1,1))
plt.title('Marial Status Distribution')
plt.show()

# %%
city_per=data2['City_Category'].value_counts()/sum(data2['City_Category'].value_counts())*100
plt.pie(city_per,labels=city_per.index.tolist(),autopct='%.1f%%')
plt.legend(labels=city_per.index.tolist())
plt.title('City Category Distribution')
plt.show()

# %%
stay_years_per=data2['Stay_In_Current_City_Years'].value_counts()/sum(data2['Stay_In_Current_City_Years'].value_counts())*100
plt.pie(stay_years_per,labels=stay_years_per.index.tolist(),autopct='%.1f%%')
plt.legend(stay_years_per.index.tolist(),loc='upper right',bbox_to_anchor=(1.1,1))
plt.title('Stay In Current City Years Distribution')
plt.show()

# %%
#
occ_unique_values=data['Occupation'].value_counts().sort_index()
sns.barplot(x=occ_unique_values.index,y=occ_unique_values.values)
plt.xlabel("Occupation")
plt.ylabel('Count')
plt.title('Occupation Distribution')
plt.show()

# %%
#city_cat=data['Occupation'].value_counts().sort_index()
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(10,8)})
sns.barplot(x=data['City_Category'].value_counts().index,y=data['City_Category'].value_counts().values,width=0.5)
plt.xlabel("City_Category")
plt.ylabel('Count')
plt.title('City Category Distribution')
plt.show()

# %%
#city_cat=data['Occupation'].value_counts().sort_index()

import seaborn as sns
import matplotlib.pyplot as plt


sns.barplot(x=data['Stay_In_Current_City_Years'].value_counts().index,y=data['Stay_In_Current_City_Years'].value_counts().values,width=0.5, linestyle='-')

plt.xlabel("Stay In Current City Years")
plt.ylabel('Count')
plt.title('Stay In Current City Years Distribution')
plt.show()

# %%
sns.countplot(x=data2['Product_Category_1'])
plt.xlabel('Product Category 1')
plt.title('Product Category 1 Distribution')
plt.show()

# %%
sns.countplot(x=data2['Product_Category_2'])
plt.xlabel('Product Category 2')

plt.title('Product Category 2 Distribution')
plt.show()

# %%
sns.countplot(x=data2['Product_Category_3'])
plt.xlabel('Product Category 3')
plt.title('Product Category 3 Distribution')
plt.show()

# %% [markdown]
# # multivariate analysis

# %%
# data2['Age']=pd.Categorical(data2['City_Category'],['A','B','C'])#sort x axis in ordersns.barplot(data=data2,x='City_Category',y='Purchase')
ax=sns.barplot(data=data2,x='Age',y='Purchase')
for container in ax.containers:
  ax.bar_label(container,fmt='%.1f')
plt.xlabel('Age')
plt.title('Different Age Average Purchase')
plt.show()

# %%
# data2['Age']=pd.Categorical(data2['City_Category'],['A','B','C'])#sort x axis in ordersns.barplot(data=data2,x='City_Category',y='Purchase')
ax=sns.barplot(data=data2,x='Gender',y='Purchase')
for container in ax.containers:
  ax.bar_label(container,fmt='%.1f')
plt.xlabel('Gender')
plt.title('Different Gender Average Purchase')
plt.show()

# %%
# data2['Age']=pd.Categorical(data2['City_Category'],['A','B','C'])#sort x axis in ordersns.barplot(data=data2,x='City_Category',y='Purchase')
ax=sns.barplot(data=data2,x='Marital_Status',y='Purchase')
for container in ax.containers:
  ax.bar_label(container,fmt='%.1f')
plt.xlabel('Marital Status')
plt.title('Different Marital Status Average Purchase')
plt.show()

# %%
data2['City_Category']=pd.Categorical(data2['City_Category'],['A','B','C'])#sort x axis in ordersns.barplot(data=data2,x='City_Category',y='Purchase')
ax=sns.barplot(data=data2,x='City_Category',y='Purchase')
for container in ax.containers:
  ax.bar_label(container,fmt='%.1f')
plt.xlabel('City Category')
plt.title('Different City Average Purchase')
plt.show()

# %%
data2['Stay_In_Current_City_Years']=pd.Categorical(data2['Stay_In_Current_City_Years'],['0', '1', '2', '3', '4+'])#order the x axies.
ax=sns.barplot(data=data2,x='Stay_In_Current_City_Years',y='Purchase',hue='City_Category')
for container in ax.containers:
  ax.bar_label(container,fmt='%.1f')
plt.xlabel('Stay In Current City Years')
plt.legend(bbox_to_anchor=(1.05,1),title='City Category')
plt.show()

# %%
purchase_by_stay_years=data2.groupby('Stay_In_Current_City_Years')['Purchase']

# %%
#occupation vs purchase (#y as mean)
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(data=data,x='Occupation',y='Purchase')
plt.title('Occupation Mean Of The Purchase Distribution')
plt.show()

# %%
#
ax=sns.barplot(x='Purchase',y='Age',hue='Marital_Status',data=data,order=data['Age'].value_counts().sort_index().index,orient='h')
# sns.set(rc={'figure.figsize':(15,8)})
for container in ax.containers:
  ax.bar_label(container,fmt='%.1f')
plt.title(' Average Purchase of age and gender')
plt.legend(title='Marital Status',loc='upper right',bbox_to_anchor=(1.2,1.0))
plt.show()
#conclusion: general in all age, male mean of purchase higher than female;female, as aged, purchase level raise.

# %%
#occupation vs purchase
import seaborn as sns
import matplotlib.pyplot as plt
# sns.set(rc={'figure.figsize':(150,8)})
sns.barplot(data=data,x='Occupation',y='Purchase',hue='City_Category')
plt.title('Occupation And City Category Purchase Distribution')
plt.legend(loc='upper right')
plt.show()

# %%
#occupation vs purchase
import seaborn as sns
import matplotlib.pyplot as plt
orders=data['Stay_In_Current_City_Years'].value_counts().index#Index(['1', '2', '3', '4+', '0'], dtype='object')
ax=sns.barplot(data=data,x='Stay_In_Current_City_Years',y='Purchase',hue='Gender',width=0.5,order=orders)
# ax=sns.barplot(data=data,x='Gender',y='Purchase',width=0.5)
for container in ax.containers:
  ax.bar_label(container,fmt='%.1f')
plt.title('Gender And Stay In Current City Purchase Distribution')
plt.xlabel('Stay In Current City Years')
plt.legend(loc='upper left',title='Gender',bbox_to_anchor=(1.02,1) )
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
orders=data['Stay_In_Current_City_Years'].value_counts().index

ax=sns.barplot(data=data,x='Stay_In_Current_City_Years',y='Purchase',hue='City_Category',width=0.5,order=orders)
for container in ax.containers:
  ax.bar_label(container,fmt='%.1f')


plt.title('City Category and Stay In Current City Years Purchase Distribution')
plt.xlabel('Stay In Current Years')
plt.legend(bbox_to_anchor=(1.08,1),title='City Category')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# sns.set(rc={'figure.figsize':(150,8)})
sns.barplot(data=data,x='Product_Category_1',y='Purchase')
plt.title('Product Category 1 Purchase Distribution')
plt.xlabel('Product Category 1')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(data=data,x='Product_Category_2',y='Purchase')
plt.title('Product Category 2 Mean Of The Purchase Distribution')
plt.xlabel('Product Category 2')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(data=data,x='Product_Category_3',y='Purchase')
plt.title('Product Categorty 3 Mean Of The Purchase Distribution')
plt.xlabel('Product Category 3')
plt.show()

# %%
import matplotlib.pyplot as plt
x_ax=range(len(data2['Purchase']))
plt.scatter(x_ax,data2['Purchase'])
plt.xlabel('Data point index')
plt.ylabel('Purchase value')
plt.title('Scatter plot of purchase values')
plt.show()

# %% [markdown]
# # data preprocessing

# %%
data2=data2.fillna(0)
data2.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
#square root transformation--feature transformation
data2['Purchase']=data2['Purchase']**(.5)

# %%
#before use factorize, fill nan as 0, or it gonna assign missing value negative label
#convert categorical data into numeric data called feature engineering
data2['User_ID']=pd.factorize(data2['User_ID'])[0]
data2['Product_ID']=pd.factorize(data2['Product_ID'])[0]
data2['Gender']=pd.factorize(data2.Gender)[0]
data2['Age']=pd.factorize(data2.Age)[0]
data2['City_Category']=pd.factorize(data2.City_Category)[0]
data2['Stay_In_Current_City_Years']=pd.factorize(data2.Stay_In_Current_City_Years)[0]

data2['Product_Category_1']=pd.factorize(data2.Product_Category_1)[0]
data2['Product_Category_2']=pd.factorize(data2.Product_Category_2)[0]
data2['Product_Category_3']=pd.factorize(data2.Product_Category_3)[0]

# %%
data2.describe(include='all')
# Out:
#              User_ID     Product_ID         Gender            Age  \
# count  550068.000000  550068.000000  550068.000000  550068.000000
# mean     2729.172659     935.727557       0.753105       3.453773
# std      1559.474869     775.658460       0.431205       1.759929
# min         0.000000       0.000000       0.000000       0.000000
# 25%      1382.000000     312.000000       1.000000       2.000000
# 50%      2772.000000     732.000000       1.000000       3.000000
# 75%      4019.000000    1374.000000       1.000000       5.000000
# max      5890.000000    3630.000000       1.000000       6.000000
#
#           Occupation  City_Category  Stay_In_Current_City_Years  \
# count  550068.000000  550068.000000               550068.000000
# mean        8.076707       1.151714                    2.098561
# std         6.522660       0.815963                    1.333504
# min         0.000000       0.000000                    0.000000
# ...

# %%
data2.head(10)
# Out:
#    User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0        0           0       0    0          10              0
# 1        0           1       0    0          10              0
# 2        0           2       0    0          10              0
# 3        0           3       0    0          10              0
# 4        1           4       1    1          16              1
# 5        2           5       1    2          15              0
# 6        3           6       1    3           7              2
# 7        3           7       1    3           7              2
# 8        3           8       1    3           7              2
# 9        4           9       1    2          20              0
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           0               0                   0
# 1                           0               0                   1
# 2                           0               0                   2
# ...

# %%
corr=data2.corr()

# %%
import seaborn as sns
sns.heatmap(corr,annot=True,fmt='.2f',linewidth=.5,cmap="Blues",vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
data2.skew().sort_values(ascending=False)
# Out:
# Product_Category_3            1.914305
# Product_Category_1            1.761399
# Product_Category_2            1.120664
# Product_ID                    1.057811
# Occupation                    0.400140
# Marital_Status                0.367437
# Age                           0.146511
# User_ID                       0.026779
# Purchase                     -0.139588
# City_Category                -0.284962
# Stay_In_Current_City_Years   -0.306796
# Gender                       -1.173946
# dtype: float64

# %% [markdown]
# # feature selection&independent, dependent

# %%
x=data2.drop(['Purchase','User_ID'],axis=1)
y=data2['Purchase']

# %%
x.isnull().sum()
# Out:
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# dtype: int64

# %% [markdown]
# # training testing split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# # feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
linear=LinearRegression()
linear.fit(x_train,y_train)
y_pred=linear.predict(x_test)
linear_mse=mean_squared_error(y_test,y_pred)
linear_mae=mean_absolute_error(y_test,y_pred)
linear_r2=r2_score(y_test,y_pred)
linear_rmse=mean_squared_error(y_test,y_pred,squared=False)
print('MSE:',linear_mse)
print('MAE:',linear_mae)
print('R2:',linear_r2)
print('RMSE',linear_rmse)
# Out:
# MSE: 22279345.14263192
# MAE: 3686.0873400583773
# R2: 0.11597881656967046
# RMSE 4720.100119979651

# %%
pip install --upgrade scikit-learn

# %% [markdown]
# # ridge regression

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
ridge_model=Ridge().fit(x_train,y_train)
y_pred=ridge_model.predict(x_test)
ridge_rmse=mean_squared_error(y_test,y_pred,squared=False)
ridge_mse=mean_squared_error(y_test,y_pred)
ridge_mae=mean_absolute_error(y_test,y_pred)
ridge_r2=r2_score(y_test,y_pred)
print('RMSE',ridge_rmse)
print('MSE:',ridge_mse)
print('MAE:',ridge_mae)
print('R2:',ridge_r2)


#RMSE 5020.24458672147 alpha=5
#RMSE 5020.244588329066 alpha=none
# Out:
# RMSE 4720.100126841627
# MSE: 22279345.207410343
# MAE: 3686.0873442763805
# R2: 0.11597881399932997

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
ridge_model=Ridge(alpha=5).fit(x_train,y_train)
y_pred=ridge_model.predict(x_test)
print('RMSE',mean_squared_error(y_test,y_pred,squared=False))
print('MSE:',mean_squared_error(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
print('R2:',r2_score(y_test,y_pred))
# Out:
# RMSE 4720.100154310086
# MSE: 22279345.466718093
# MAE: 3686.087361154738
# R2: 0.11597880371026903

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
ridge_model=Ridge(alpha=114.9).fit(x_train,y_train)
y_pred=ridge_model.predict(x_test)
print('RMSE',mean_squared_error(y_test,y_pred,squared=False))
print('MSE:',mean_squared_error(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
print('R2:',r2_score(y_test,y_pred))
# Out:
# RMSE 4720.10092182632
# MSE: 22279352.712225676
# MAE: 3686.0878631809537
# R2: 0.11597851621608324

# %%
#alpha tuning
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
import numpy as np
ridge_regression=Ridge()
alpha_range=np.logspace(-4,4,100)
parameters={'alpha': alpha_range }
regression_scoring=['neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error','r2']
for i in regression_scoring:
  ridge_cv=GridSearchCV(ridge_regression,parameters,scoring=i,cv=5)
  ridge_cv.fit(x_train,y_train)
  print(f"Best lambda value for {i} : ,{ridge_cv.best_params_}")
  print(f"Best score cost function for {i} : ,{ridge_cv.best_score_}")
# Out:
# Best lambda value for neg_mean_absolute_error : ,{'alpha': 1555.6761439304755}
# Best score cost function for neg_mean_absolute_error : ,-3686.0352892189826
# Best lambda value for neg_mean_squared_error : ,{'alpha': 114.9756995397738}
# Best score cost function for neg_mean_squared_error : ,-22241693.261947062
# Best lambda value for neg_root_mean_squared_error : ,{'alpha': 114.9756995397738}
# Best score cost function for neg_root_mean_squared_error : ,-4716.085164697505
# Best lambda value for r2 : ,{'alpha': 114.9756995397738}
# Best score cost function for r2 : ,0.11890589493905464

# %% [markdown]
# # LASSO regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
lasso=Lasso()
lasso.fit(x_train,y_train)
y_pred=lasso.predict(x_test)
lasso_rmse=mean_squared_error(y_test,y_pred,squared=False)

lasso_mse=mean_squared_error(y_test,y_pred)
lasso_mae=mean_absolute_error(y_test,y_pred)
lasso_r2=r2_score(y_test,y_pred)
print('RMSE',lasso_rmse)
print('MSE:',lasso_mse)
print('MAE:',lasso_mae)
print('R2:',lasso_r2)
# Out:
# RMSE 4720.117061351045
# MSE: 22279505.072857223
# MAE: 3686.139878931578
# R2: 0.11597247070509775

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
lasso=Lasso(alpha=0.0001)
lasso.fit(x_train,y_train)
y_pred=lasso.predict(x_test)
print('RMSE',mean_squared_error(y_test,y_pred,squared=False))
print('MSE:',mean_squared_error(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
print('R2:',r2_score(y_test,y_pred))
# Out:
# RMSE 4720.100121545156
# MSE: 22279345.157410596
# MAE: 3686.0873451549005
# R2: 0.11597881598326798

# %%
#hyperparamters tuning
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
import numpy as np

alpha_range=np.logspace(-4,4,100)
parameters={'alpha': alpha_range }
regression_scoring=['neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error','r2']
for i in regression_scoring:
  ridge_cv=GridSearchCV(lasso,parameters,scoring=i,cv=5)
  ridge_cv.fit(x_train,y_train)
  print(f"Best lambda value for {i} : ,{ridge_cv.best_params_}")
  print(f"Best score cost function for {i} : ,{ridge_cv.best_score_}")
# Out:
# Best lambda value for neg_mean_absolute_error : ,{'alpha': 0.0001}
# Best score cost function for neg_mean_absolute_error : ,-3686.0415885559623
# Best lambda value for neg_mean_squared_error : ,{'alpha': 0.0001}
# Best score cost function for neg_mean_squared_error : ,-22241693.482332475
# Best lambda value for neg_root_mean_squared_error : ,{'alpha': 0.0001}
# Best score cost function for neg_root_mean_squared_error : ,-4716.085189692525
# Best lambda value for r2 : ,{'alpha': 0.0001}
# Best score cost function for r2 : ,0.11890588512724301

# %% [markdown]
# # Model Selection

# %%
from zmq.sugar.frame import Message
regression_models=['Linear','Lasso','Ridge']
rmse_values=[linear_rmse,lasso_rmse,ridge_rmse]
mse_values=[linear_mse,lasso_mse,ridge_mse]
mae_values=[linear_mae,lasso_mae,ridge_mae]
r2_values=[linear_r2,lasso_r2,ridge_r2]

error_metrics_df=pd.DataFrame({'Models':regression_models,'RMSE':rmse_values,'MSE':mse_values,'MAE':mae_values,'R2':r2_values})
error_metrics_df=error_metrics_df.set_index('Models')
error_metrics_df
# Out:
#                RMSE           MSE          MAE        R2
# Models
# Linear  4720.100120  2.227935e+07  3686.087340  0.115979
# Lasso   4720.117061  2.227951e+07  3686.139879  0.115972
# Ridge   4720.100127  2.227935e+07  3686.087344  0.115979

# %%
error_metrics_df=error_metrics_df.set_index('Models')
error_metrics_df
# Out:
#                RMSE           MSE          MAE        R2
# Models
# Linear  4720.100120  2.227935e+07  3686.087340  0.115979
# Lasso   4720.117061  2.227951e+07  3686.139879  0.115972
# Ridge   4720.100127  2.227935e+07  3686.087344  0.115979

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax= sns.lineplot(x='Models', y='R2', data=error_metrics_df)

# %%
import matplotlib.pyplot as plt

# Create a figure with two subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 6))

# Visualization of RMSE comparison
axes[0, 0].plot(error_metrics_df.index, error_metrics_df['RMSE'], marker='o', color='blue')
axes[0, 0].set_xlabel('Models')
axes[0, 0].set_ylabel('RMSE')
axes[0, 0].set_title('RMSE Comparison')

# Visualization of MSE comparison
axes[0, 1].plot(error_metrics_df.index, error_metrics_df['MSE'], marker='o', color='orange')
axes[0, 1].set_xlabel('Models')
axes[0, 1].set_ylabel('MSE')
axes[0, 1].set_title('MSE Comparison')

# Visualization of MAE comparison
axes[1, 0].plot(error_metrics_df.index, error_metrics_df['MAE'], marker='o', color='green')
axes[1, 0].set_xlabel('Models')
axes[1, 0].set_ylabel('MAE')
axes[1, 0].set_title('MAE Comparison')

# Visualization of R2 comparison
axes[1, 1].plot(error_metrics_df.index, error_metrics_df['R2'], marker='o', color='red')
axes[1, 1].set_xlabel('Models')
axes[1, 1].set_ylabel('R2')
axes[1, 1].set_title('R2 Comparison')

# Adjust layout and display the figure
plt.tight_layout()
plt.show()

# %% [markdown]
# # Decission tree regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

decission_tree=DecisionTreeRegressor()
decission_tree.fit(x_train,y_train)
y_pred=decission_tree.predict(x_test)

decission_rmse=mean_squared_error(y_test,y_pred,squared=False)
decission_mse=mean_squared_error(y_test,y_pred)
decission_mae=mean_absolute_error(y_test,y_pred)
decission_r2=r2_score(y_test,y_pred)

print('RMSE',decission_rmse)
print('MSE:',decission_mse)
print('MAE:',decission_mae)
print('R2:',decission_r2)
# Out:
# RMSE 3751.6446624258415
# MSE: 14074837.673108306
# MAE: 2650.317061410572
# R2: 0.4415251176946787

# %%
x_ax=range(len(y_test))
plt.plot(x_ax,y_test,label='original')
plt.plot(x_ax,y_pred,label='predicted')
plt.title('y_test and y_pred data')
plt.legend(bbox_to_anchor=(1.05,1))
plt.show()

# %% [markdown]
# # Random forest decision

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest=RandomForestRegressor(random_state=42)
random_forest.fit(x_train,y_train)
random_forest_pred=random_forest.predict(x_test)

# %%
from matplotlib import pyplot as plt
x_ax=range(len(y_test))
plt.plot(x_ax,random_forest_pred,'ro',label='prediction')
plt.plot(x_ax,y_test,'bo',label='original')
plt.title('y_test and y_pred data')
plt.legend(bbox_to_anchor=(1.05,1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-41684302377e> in <cell line: 2>()
#       1 from matplotlib import pyplot as plt
# ----> 2 x_ax=range(len(y_test))
#       3 plt.plot(x_ax,random_forest_pred,'ro',label='prediction')
#       4 plt.plot(x_ax,y_test,'bo',label='original')
#       5 plt.title('y_test and y_pred data')
#
# NameError: name 'y_test' is not defined

# %%
importances=random_forest.feature_importances_
importances
# Out:
# array([0.11187212, 0.01439648, 0.04330693, 0.0788702 , 0.03073878,
#        0.04955946, 0.01916821, 0.62257824, 0.01854916, 0.01096041])

# %%
import numpy as np
sorted_indices=np.argsort(importances)[::-1]
sorted_indices
# Out:
# array([7, 0, 3, 5, 2, 4, 6, 8, 1, 9])

# %%
feat_labels=x.columns
feat_labels
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
for f in range(x_train.shape[1]):
  print("%2d) %-*s %f" %(f+1,30,feat_labels[sorted_indices[f]], importances[sorted_indices[f]]))
# Out:
#  1) Product_Category_1             0.622578
#  2) Product_ID                     0.111872
#  3) Occupation                     0.078870
#  4) Stay_In_Current_City_Years     0.049559
#  5) Age                            0.043307
#  6) City_Category                  0.030739
#  7) Marital_Status                 0.019168
#  8) Product_Category_2             0.018549
#  9) Gender                         0.014396
# 10) Product_Category_3             0.010960

# %%
import matplotlib.pyplot as plt
plt.title('Feature Importance')
plt.bar(range(x_train.shape[1]),importances[sorted_indices],align='center')
plt.xticks(range(x_train.shape[1]),feat_labels[sorted_indices],rotation=90)
plt.tight_layout()
plt.show()

# %%
from pprint import pprint
print('Parameters currently in use:\n')
pprint(random_forest.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import RandomizedSearchCV

n_estimators=[int(x) for x in np.linspace(start=200,stop=2000,num=10)]

max_features=['auto','sqrt']

max_depth=[int(x)for x in np.linspace(10,100,num=11)]
max_depth.append(None)

min_samples_split=[2,5,10]

min_samples_leaf=[1,2,4]

bootstrap=[True,False]

random_grid={
    'n_estimators': n_estimators,
    'max_features':max_features,
    'max_depth':max_depth,
    'min_samples_split':min_samples_split,
    'min_samples_leaf': min_samples_leaf,
    'bootstrap':bootstrap
}

pprint(random_grid)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [10, 19, 28, 37, 46, 55, 64, 73, 82, 91, 100, None],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4],
#  'min_samples_split': [2, 5, 10],
#  'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000]}

# %%
rf=RandomForestRegressor(random_state=42)
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=10,cv=3,verbose=2,random_state=42,n_jobs=-1,return_train_score=True)
rf_random.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# ---------------------------------------------------------------------------
# TerminatedWorkerError                     Traceback (most recent call last)
# <ipython-input-20-f8624688562b> in <cell line: 3>()
#       1 rf=RandomForestRegressor(random_state=42)
#       2 rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=10,cv=3,verbose=2,random_state=42,n_jobs=-1,return_train_score=True)
# ----> 3 rf_random.fit(x_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
# ...
